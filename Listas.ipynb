# %% [markdown]
# <a href="https://colab.research.google.com/github/bernardoferreira678/PROVA_A1/blob/main/Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Listas
# Projeto: Gerenciador de Tarefas
# Descrição: Permite adicionar, listar e remover tarefas usando uma lista.

# %%
# Lista que armazenará as tarefas
tarefas = []

# Loop principal do programa
while True:
    print("\n--- MENU DE TAREFAS ---")
    print("1 - Adicionar tarefa")
    print("2 - Listar tarefas")
    print("3 - Remover tarefa")
    print("4 - Sair")

    opcao = input("Escolha uma opção: ")

    # Adicionar tarefa
    if opcao == "1":
        tarefa = input("Digite a tarefa: ")
        tarefas.append(tarefa)
        print("Tarefa adicionada!")

    # Listar tarefas
    elif opcao == "2":
        print("\nTarefas cadastradas:")
        for i, t in enumerate(tarefas, start=1):
            print(f"{i}. {t}")

    # Remover tarefa
    elif opcao == "3":
        try:
            num = int(input("Digite o número da tarefa para remover: "))
            tarefas.pop(num - 1)
            print("Tarefa removida!")
        except:
            print("Erro! Número inválido.")

    # Sair
    elif opcao == "4":
        print("Saindo...")
        break

    else:
        print("Opção inválida!")
