# %% [markdown]
# <a href="https://colab.research.google.com/github/bernardoferreira678/PROVA_A1/blob/main/Estruturas_de_Repeti%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Projeto: Tabuada Automática
# Descrição: Gera a tabuada do número informado pelo usuário.
# Estruturas de Repetição

# %%
# Recebe o número do usuário
numero = int(input("Digite um número para ver sua tabuada: "))

# Laço de repetição para gerar a tabuada
for i in range(1, 11):
    print(f"{numero} x {i} = {numero * i}")
