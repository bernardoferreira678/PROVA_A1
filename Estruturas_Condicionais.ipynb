# %% [markdown]
# <a href="https://colab.research.google.com/github/bernardoferreira678/PROVA_A1/blob/main/Estruturas_Condicionais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estruturas Condicionais
# Projeto: Classificação de Faixa Etária
# Descrição: O programa recebe a idade do usuário e informa a categoria correspondente.

# %%
# Solicita a idade ao usuário
idade = int(input("Digite sua idade: "))

# Estruturas condicionais para classificar a idade
if idade < 0:
    print("Idade inválida.")
elif idade <= 12:
    print("Você é uma criança.")
elif idade <= 17:
    print("Você é um adolescente.")
elif idade <= 59:
    print("Você é um adulto.")
else:
    print("Você é um idoso.")
